# %% [markdown]
# Online Car sales data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
# loading the data from the database python.db
# loading the data from the database python.db
Online_Cars_Sale_Marketplace_df = pd.read_csv('./data/Online_Cars_Sale_Marketplace.csv')

# %%
Online_Cars_Sale_Marketplace_df.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Used/New', 'Price', 'ConsumerRating',
#        'ConsumerReviews', 'SellerType', 'SellerName', 'SellerRating',
#        'SellerReviews', 'StreetName', 'State', 'Zipcode', 'DealType',
#        'ComfortRating', 'InteriorDesignRating', 'PerformanceRating',
#        'ValueForMoneyRating', 'ExteriorStylingRating', 'ReliabilityRating',
#        'ExteriorColor', 'InteriorColor', 'Drivetrain', 'MinMPG', 'MaxMPG',
#        'FuelType', 'Transmission', 'Engine', 'VIN', 'Stock#', 'Mileage'],
#       dtype='object')

# %%
# First, make a copy of the dataset
df = Online_Cars_Sale_Marketplace_df.copy()

# Check the exact unique values in 'Price' column
print(df['Price'].unique())
# Out:
# ['$39,998' '$49,985' '$41,860' ... '$26,944' '$28,568' '$32,091']

# %%
df['Price'] = df['Price'].astype(str)

# Drop rows where 'Price' is 'not priced'
df = df[df['Price'].str.lower() != 'not priced']

# Remove $ and commas from 'Price' and convert to integer
df['Price'] = df['Price'].str.replace('$', '', regex=False)
df['Price'] = df['Price'].str.replace(',', '', regex=False)
df['Price'] = df['Price'].astype(int)

# Ensure 'Used/New' is string before string operations
df['Used/New'] = df['Used/New'].astype(str).str.lower()
df['Used/New'] = df['Used/New'].replace(to_replace=r'certified.*', value='Certified', regex=True)
df['Used/New'] = df['Used/New'].str.title()

# Check cleaned output
print(df['Price'].head())
print(df['Used/New'].unique())
df.head(40)
# Out:
# 0    39998
# 1    49985
# 2    41860
# 3    28500
# 4    49000
# Name: Price, dtype: int32
# ['Used' 'Certified']
#     Year           Make                                Model   Used/New  \
# 0   2019         Toyota                            Sienna SE       Used
# 1   2018           Ford                         F-150 Lariat       Used
# 2   2017            RAM                         1500 Laramie       Used
# 3   2021          Honda                      Accord Sport SE       Used
# 4   2020          Lexus                               RX 350       Used
# 5   2012         Toyota                          4Runner SR5       Used
# 6   2017          Honda                              HR-V LX       Used
# 7   2014  Mercedes-Benz                        E-Class E 350       Used
# 8   2021          Honda            Pilot Touring 8-Passenger       Used
# 9   2020          Dodge                    Charger Scat Pack  Certified
# ...

# %% [markdown]
# Change to certified

# %%
# Ensure 'Price' is a string first
df['Price'] = df['Price'].astype(str)

# Drop rows where 'Price' is 'not priced'
df = df[df['Price'].str.lower() != 'not priced']

# Remove $ and commas from 'Price' and convert to integer
df['Price'] = df['Price'].str.replace('$', '', regex=False)
df['Price'] = df['Price'].str.replace(',', '', regex=False)
df['Price'] = df['Price'].astype(int)

# Ensure 'Used/New' is string before string operations
df['Used/New'] = df['Used/New'].astype(str).str.lower()
df['Used/New'] = df['Used/New'].replace(to_replace=r'certified.*', value='Certified', regex=True)
df['Used/New'] = df['Used/New'].str.title()









# Make sure the column is string type
df['Used/New'] = df['Used/New'].astype(str)

# Replace any value that contains the word 'certified' (case insensitive) with 'Certified'
df['Used/New'] = df['Used/New'].str.lower().replace(to_replace=r'.*certified.*', value='Certified', regex=True)

# Capitalize first letters for consistency (e.g., 'used' becomes 'Used')
df['Used/New'] = df['Used/New'].str.title()

# Check the unique values to confirm it worked
print(df['Used/New'].unique())

# Check cleaned output
print(df['Price'].head())
print(df['Used/New'].unique())
df.head(40)
# Out:
# ['Used' 'Certified']
# 0    39998
# 1    49985
# 2    41860
# 3    28500
# 4    49000
# Name: Price, dtype: int32
# ['Used' 'Certified']
#     Year           Make                                Model   Used/New  \
# 0   2019         Toyota                            Sienna SE       Used
# 1   2018           Ford                         F-150 Lariat       Used
# 2   2017            RAM                         1500 Laramie       Used
# 3   2021          Honda                      Accord Sport SE       Used
# 4   2020          Lexus                               RX 350       Used
# 5   2012         Toyota                          4Runner SR5       Used
# 6   2017          Honda                              HR-V LX       Used
# 7   2014  Mercedes-Benz                        E-Class E 350       Used
# 8   2021          Honda            Pilot Touring 8-Passenger       Used
# 9   2020          Dodge                    Charger Scat Pack  Certified
# ...

# %% [markdown]
# 3. Remove rows from the data where the value for 'drivetrain' is '-' . These were most likely cases
# where the seller did not input the drivetrain information. (You can also impute this data if you
# feel comfortable doing so).

# %%
df['Price'] = df['Price'].astype(str)

# Drop rows where 'Price' is 'not priced'
df = df[df['Price'].str.lower() != 'not priced']

# Remove $ and commas from 'Price' and convert to integer
df['Price'] = df['Price'].str.replace('$', '', regex=False)
df['Price'] = df['Price'].str.replace(',', '', regex=False)
df['Price'] = df['Price'].astype(int)

# Ensure 'Used/New' is string before string operations
df['Used/New'] = df['Used/New'].astype(str).str.lower()
df['Used/New'] = df['Used/New'].replace(to_replace=r'certified.*', value='Certified', regex=True)
df['Used/New'] = df['Used/New'].str.title()


# Remove rows where 'Drivetrain' value is just a dash
df = df[df['Drivetrain'] != '-']

# Check unique values after cleaning
print(df['Drivetrain'].unique())








# Check cleaned output
print(df['Price'].head())
print(df['Used/New'].unique())
df.head(40)
# Out:
# ['Front-wheel Drive' 'Four-wheel Drive' 'Rear-wheel Drive'
#  'All-wheel Drive' '4WD' 'AWD' 'RWD' 'FWD' 'Front Wheel Drive' '–']
# 0    39998
# 1    49985
# 2    41860
# 3    28500
# 4    49000
# Name: Price, dtype: int32
# ['Used' 'Certified']
#     Year           Make                                Model   Used/New  \
# 0   2019         Toyota                            Sienna SE       Used
# 1   2018           Ford                         F-150 Lariat       Used
# 2   2017            RAM                         1500 Laramie       Used
# 3   2021          Honda                      Accord Sport SE       Used
# 4   2020          Lexus                               RX 350       Used
# 5   2012         Toyota                          4Runner SR5       Used
# 6   2017          Honda                              HR-V LX       Used
# 7   2014  Mercedes-Benz                        E-Class E 350       Used
# 8   2021          Honda            Pilot Touring 8-Passenger       Used
# ...
