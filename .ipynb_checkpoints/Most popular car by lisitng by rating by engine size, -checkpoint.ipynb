# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('./data/Online_Cars_Sale_Marketplace.csv')

# %%
# loading the data from the database python.db
df = pd.read_csv('./data/Online_Cars_Sale_Marketplace.csv')

# %%
Online_Cars_Sale_Marketplace_df.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Used/New', 'Price', 'ConsumerRating',
#        'ConsumerReviews', 'SellerType', 'SellerName', 'SellerRating',
#        'SellerReviews', 'StreetName', 'State', 'Zipcode', 'DealType',
#        'ComfortRating', 'InteriorDesignRating', 'PerformanceRating',
#        'ValueForMoneyRating', 'ExteriorStylingRating', 'ReliabilityRating',
#        'ExteriorColor', 'InteriorColor', 'Drivetrain', 'MinMPG', 'MaxMPG',
#        'FuelType', 'Transmission', 'Engine', 'VIN', 'Stock#', 'Mileage'],
#       dtype='object')

# %% [markdown]
# Popular by lisiting

# %%
# Most Frequently Listed (Quantity-Based Popularity)
df['Car'] = df['Make'] + ' ' + df['Model']

# Find the top 10 most listed cars
popular_listings = df['Car'].value_counts().head(10)
print(popular_listings)
# Out:
# Car
# Jeep Grand Cherokee Limited    266
# Honda CR-V EX-L                189
# BMW X5 xDrive40i               164
# Cadillac XT5 Luxury            142
# Toyota RAV4 LE                 112
# Lexus GX 460 Base              111
# BMW X3 xDrive30i               108
# Honda Pilot EX-L               102
# Mazda CX-5 Grand Touring        99
# RAM 1500 Laramie                88
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(10,6))
popular_listings.plot(kind='barh', color='dodgerblue')

# Titles and labels
plt.title('Top 10 Most Listed Cars on the Platform')
plt.xlabel('Number of Listings')
plt.ylabel('Car')

# Invert y-axis so highest is at top
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Reset index to make plotting easier
top_rated = top_rated.reset_index()

# Plot
plt.figure(figsize=(10,6))
plt.barh(top_rated['Make'] + ' ' + top_rated['Model'], top_rated['ConsumerRating'], color='skyblue')
plt.xlabel('Average Consumer Rating')
plt.title('Top 10 Highest-Rated Cars')
plt.gca().invert_yaxis()  # highest rating on top
plt.tight_layout()
plt.show()

# %% [markdown]
# Popular by rating

# %%
df['ConsumerRating'] = pd.to_numeric(df['ConsumerRating'], errors='coerce')

# Group by Make and Model, calculate average rating, then sort
top_rated = df.groupby(['Make', 'Model'])['ConsumerRating'].mean().sort_values(ascending=False).head(10)

# Show result
print(top_rated)
# Out:
# Make           Model
# Audi           A4 40 Premium                   5.0
# BMW            M5 Competition                  5.0
# Cadillac       Escalade ESV Premium Luxury     5.0
# Audi           A4 45 S line quattro Premium    5.0
#                A4 40 Premium Plus              5.0
# Lexus          RX 350L Base                    5.0
# BMW            750 i                           5.0
# Cadillac       Escalade ESV Luxury             5.0
# Genesis        GV70 2.5T                       5.0
# Mercedes-Benz  AMG E 63 S 4MATIC               5.0
# Name: ConsumerRating, dtype: float64

# %%
print(df['ConsumerRating'].head(10))
print(df['ConsumerRating'].dtype)
print(df['ConsumerRating'].isna().sum())
# Out:
# 0    4.6
# 1    4.8
# 2    4.7
# 3    5.0
# 4    4.8
# 5    4.7
# 6    4.6
# 7    4.8
# 8    4.8
# 9    4.8
# Name: ConsumerRating, dtype: float64
# float64
# 0

# %%
df['ConsumerRating'] = pd.to_numeric(df['ConsumerRating'], errors='coerce')
df_rating = df.dropna(subset=['ConsumerRating'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.scatterplot(data=df_rating, x='Price', y='ConsumerRating', hue='Used/New', alpha=0.7)
plt.title('Price vs. Consumer Rating')
plt.xlabel('Price ($)')
plt.ylabel('Consumer Rating')
plt.show()

# %% [markdown]
# Popular by Engine size

# %%
engine_popularity = df['Engine'].value_counts().head(10)

# Display the counts
print(engine_popularity)
# Out:
# Engine
# 2.0L I4 16V GDI DOHC Turbo    1629
# 1.5L I4 16V GDI DOHC Turbo     425
# 3.6L V6 24V MPFI DOHC          423
# 3.0L I6 24V GDI DOHC Turbo     417
# 3.6L V6 24V GDI DOHC           390
# 3.5L V6 24V PDI DOHC           297
# 3.5L V6 24V GDI SOHC           290
# 2.4L I4 16V GDI DOHC           230
# 2.5L I4 16V PDI DOHC           221
# 3.5L V6 24V GDI DOHC           216
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
engine_popularity.plot(kind='bar', color='orange')
plt.title('Top 10 Most Common Engine Types in Listings')
plt.xlabel('Engine Type')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
